# %% [markdown]
# # **Altair Exercise**
# ---
#
# <a href="https://midoritoyota.netlify.app/" target="_blank"><img align="left" src="portfolio.png" title="See my portfolio!"/></a><img align="left" src="espaco.png"/>
#
# <a href="mailto:midori.toyota@gmail.com" target="_blank"><img align="left" src="gmail.png" title="Contact me!"/></a><img align="left" src="espaco.png"/>
#
# <a href="https://www.linkedin.com/in/midoritoyota/" target="_blank"> <img align="left" src="linkedin.png" title="Connect with me on linkedin!" /></a><img align="left" src="espaco.png"/>
#
# <a href="https://github.com/MidoriToyota" target="_blank"> <img align="left" src="github.png" title="Follow me on github!"/></a>
#
# <br/><br/>

# %% [markdown]
# ## **Pacotes**

# %%
import altair as alt
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Getting Started**
#
# https://altair-viz.github.io/getting_started/overview.html

# %%
# Loading data
cars = pd.read_csv("cars.csv")
cars.head()
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945  $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820  $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990  $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195  $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755  $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
# Basic info
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    int64
#  10  MPG_City     428 non-null    int64
#  11  MPG_Highway  428 non-null    int64
#  12  Weight       428 non-null    int64
#  13  Wheelbase    428 non-null    int64
#  14  Length       428 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 50.3+ KB

# %%
# Basic chart
alt.Chart(cars).mark_point().encode(y = 'Origin', x = 'EngineSize')
# Out:
# alt.Chart(...)

# %%
# Aggregating functions
alt.Chart(cars).mark_point().encode(y = 'Origin', x = 'average(EngineSize)')
# Out:
# alt.Chart(...)

# %%
# Changing type of graph
alt.Chart(cars).mark_bar().encode(y = 'Origin', x = 'average(EngineSize)')
# Out:
# alt.Chart(...)

# %%
# Inspecting
chart = alt.Chart(cars).mark_bar().encode(
    x='Origin',
    y='average(EngineSize)'
)

# %%
# Inspecting chart json
print(chart.to_json())
# Out:
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v4.8.1.json",
#   "config": {
#     "view": {
#       "continuousHeight": 300,
#       "continuousWidth": 400
#     }
#   },
#   "data": {
#     "name": "data-362fecc64292928e5a32b64921b7b919"
#   },
#   "datasets": {
#     "data-362fecc64292928e5a32b64921b7b919": [
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.5,
#         "Horsepower": 265,
#         "Invoice": "$33,337",
#         "Length": 189,
#         "MPG_City": 17,
#         "MPG_Highway": 23,
#         "MSRP": "$36,945",
#         "Make": "Acura",
#         "Model": "MDX",
#         "Origin": "Asia",
#         "Type": "SUV",
#         "Weight": 4451,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.0,
#         "Horsepower": 200,
#         "Invoice": "$21,761",
#         "Length": 172,
#         "MPG_City": 24,
#         "MPG_Highway": 31,
#         "MSRP": "$23,820",
#         "Make": "Acura",
#         "Model": "RSX Type S 2dr",
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 2778,
#         "Wheelbase": 101
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 200,
#         "Invoice": "$24,647",
#         "Length": 183,
#         "MPG_City": 22,
#         "MPG_Highway": 29,
#         "MSRP": "$26,990",
#         "Make": "Acura",
#         "Model": "TSX 4dr",
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 3230,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.2,
#         "Horsepower": 270,
#         "Invoice": "$30,299",
#         "Length": 186,
#         "MPG_City": 20,
#         "MPG_Highway": 28,
#         "MSRP": "$33,195",
#         "Make": "Acura",
#         "Model": "TL 4dr",
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 3575,
#         "Wheelbase": 108
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.5,
#         "Horsepower": 225,
#         "Invoice": "$39,014",
#         "Length": 197,
#         "MPG_City": 18,
#         "MPG_Highway": 24,
#         "MSRP": "$43,755",
#         "Make": "Acura",
#         "Model": "3.5 RL 4dr",
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 3880,
#         "Wheelbase": 115
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.5,
#         "Horsepower": 225,
#         "Invoice": "$41,100",
#         "Length": 197,
#         "MPG_City": 18,
#         "MPG_Highway": 24,
#         "MSRP": "$46,100",
#         "Make": "Acura",
#         "Model": "3.5 RL w/Navigation 4dr",
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 3893,
#         "Wheelbase": 115
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.2,
#         "Horsepower": 290,
#         "Invoice": "$79,978",
#         "Length": 174,
#         "MPG_City": 17,
#         "MPG_Highway": 24,
#         "MSRP": "$89,765",
#         "Make": "Acura",
#         "Model": "NSX coupe 2dr manual S",
#         "Origin": "Asia",
#         "Type": "Sports",
#         "Weight": 3153,
#         "Wheelbase": 100
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.8,
#         "Horsepower": 170,
#         "Invoice": "$23,508",
#         "Length": 179,
#         "MPG_City": 22,
#         "MPG_Highway": 31,
#         "MSRP": "$25,940",
#         "Make": "Audi",
#         "Model": "A4 1.8T 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3252,
#         "Wheelbase": 104
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.8,
#         "Horsepower": 170,
#         "Invoice": "$32,506",
#         "Length": 180,
#         "MPG_City": 23,
#         "MPG_Highway": 30,
#         "MSRP": "$35,940",
#         "Make": "Audi",
#         "Model": "A41.8T convertible 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3638,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.0,
#         "Horsepower": 220,
#         "Invoice": "$28,846",
#         "Length": 179,
#         "MPG_City": 20,
#         "MPG_Highway": 28,
#         "MSRP": "$31,840",
#         "Make": "Audi",
#         "Model": "A4 3.0 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3462,
#         "Wheelbase": 104
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.0,
#         "Horsepower": 220,
#         "Invoice": "$30,366",
#         "Length": 179,
#         "MPG_City": 17,
#         "MPG_Highway": 26,
#         "MSRP": "$33,430",
#         "Make": "Audi",
#         "Model": "A4 3.0 Quattro 4dr manual",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3583,
#         "Wheelbase": 104
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.0,
#         "Horsepower": 220,
#         "Invoice": "$31,388",
#         "Length": 179,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$34,480",
#         "Make": "Audi",
#         "Model": "A4 3.0 Quattro 4dr auto",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3627,
#         "Wheelbase": 104
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.0,
#         "Horsepower": 220,
#         "Invoice": "$33,129",
#         "Length": 192,
#         "MPG_City": 20,
#         "MPG_Highway": 27,
#         "MSRP": "$36,640",
#         "Make": "Audi",
#         "Model": "A6 3.0 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3561,
#         "Wheelbase": 109
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.0,
#         "Horsepower": 220,
#         "Invoice": "$35,992",
#         "Length": 192,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$39,640",
#         "Make": "Audi",
#         "Model": "A6 3.0 Quattro 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3880,
#         "Wheelbase": 109
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.0,
#         "Horsepower": 220,
#         "Invoice": "$38,325",
#         "Length": 180,
#         "MPG_City": 20,
#         "MPG_Highway": 27,
#         "MSRP": "$42,490",
#         "Make": "Audi",
#         "Model": "A4 3.0 convertible 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3814,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.0,
#         "Horsepower": 220,
#         "Invoice": "$40,075",
#         "Length": 180,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$44,240",
#         "Make": "Audi",
#         "Model": "A4 3.0 Quattro convertible 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 4013,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 2.7,
#         "Horsepower": 250,
#         "Invoice": "$38,840",
#         "Length": 192,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$42,840",
#         "Make": "Audi",
#         "Model": "A6 2.7 Turbo Quattro 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3836,
#         "Wheelbase": 109
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 4.2,
#         "Horsepower": 300,
#         "Invoice": "$44,936",
#         "Length": 193,
#         "MPG_City": 17,
#         "MPG_Highway": 24,
#         "MSRP": "$49,690",
#         "Make": "Audi",
#         "Model": "A6 4.2 Quattro 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 4024,
#         "Wheelbase": 109
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 4.2,
#         "Horsepower": 330,
#         "Invoice": "$64,740",
#         "Length": 204,
#         "MPG_City": 17,
#         "MPG_Highway": 24,
#         "MSRP": "$69,190",
#         "Make": "Audi",
#         "Model": "A8 L Quattro 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 4399,
#         "Wheelbase": 121
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 4.2,
#         "Horsepower": 340,
#         "Invoice": "$43,556",
#         "Length": 179,
#         "MPG_City": 14,
#         "MPG_Highway": 20,
#         "MSRP": "$48,040",
#         "Make": "Audi",
#         "Model": "S4 Quattro 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3825,
#         "Wheelbase": 104
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 4.2,
#         "Horsepower": 450,
#         "Invoice": "$76,417",
#         "Length": 191,
#         "MPG_City": 15,
#         "MPG_Highway": 22,
#         "MSRP": "$84,600",
#         "Make": "Audi",
#         "Model": "RS 6 4dr",
#         "Origin": "Europe",
#         "Type": "Sports",
#         "Weight": 4024,
#         "Wheelbase": 109
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.8,
#         "Horsepower": 180,
#         "Invoice": "$32,512",
#         "Length": 159,
#         "MPG_City": 20,
#         "MPG_Highway": 28,
#         "MSRP": "$35,940",
#         "Make": "Audi",
#         "Model": "TT 1.8 convertible 2dr (coupe)",
#         "Origin": "Europe",
#         "Type": "Sports",
#         "Weight": 3131,
#         "Wheelbase": 95
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "All",
#         "EngineSize": 1.8,
#         "Horsepower": 225,
#         "Invoice": "$33,891",
#         "Length": 159,
#         "MPG_City": 20,
#         "MPG_Highway": 28,
#         "MSRP": "$37,390",
#         "Make": "Audi",
#         "Model": "TT 1.8 Quattro 2dr (convertible)",
#         "Origin": "Europe",
#         "Type": "Sports",
#         "Weight": 2921,
#         "Wheelbase": 96
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.2,
#         "Horsepower": 250,
#         "Invoice": "$36,739",
#         "Length": 159,
#         "MPG_City": 21,
#         "MPG_Highway": 29,
#         "MSRP": "$40,590",
#         "Make": "Audi",
#         "Model": "TT 3.2 coupe 2dr (convertible)",
#         "Origin": "Europe",
#         "Type": "Sports",
#         "Weight": 3351,
#         "Wheelbase": 96
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.0,
#         "Horsepower": 220,
#         "Invoice": "$37,060",
#         "Length": 192,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$40,840",
#         "Make": "Audi",
#         "Model": "A6 3.0 Avant Quattro",
#         "Origin": "Europe",
#         "Type": "Wagon",
#         "Weight": 4035,
#         "Wheelbase": 109
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 4.2,
#         "Horsepower": 340,
#         "Invoice": "$44,446",
#         "Length": 179,
#         "MPG_City": 15,
#         "MPG_Highway": 21,
#         "MSRP": "$49,090",
#         "Make": "Audi",
#         "Model": "S4 Avant Quattro",
#         "Origin": "Europe",
#         "Type": "Wagon",
#         "Weight": 3936,
#         "Wheelbase": 104
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.0,
#         "Horsepower": 225,
#         "Invoice": "$33,873",
#         "Length": 180,
#         "MPG_City": 16,
#         "MPG_Highway": 23,
#         "MSRP": "$37,000",
#         "Make": "BMW",
#         "Model": "X3 3.0i",
#         "Origin": "Europe",
#         "Type": "SUV",
#         "Weight": 4023,
#         "Wheelbase": 110
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 4.4,
#         "Horsepower": 325,
#         "Invoice": "$47,720",
#         "Length": 184,
#         "MPG_City": 16,
#         "MPG_Highway": 22,
#         "MSRP": "$52,195",
#         "Make": "BMW",
#         "Model": "X5 4.4i",
#         "Origin": "Europe",
#         "Type": "SUV",
#         "Weight": 4824,
#         "Wheelbase": 111
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 2.5,
#         "Horsepower": 184,
#         "Invoice": "$26,155",
#         "Length": 176,
#         "MPG_City": 20,
#         "MPG_Highway": 29,
#         "MSRP": "$28,495",
#         "Make": "BMW",
#         "Model": "325i 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3219,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 2.5,
#         "Horsepower": 184,
#         "Invoice": "$28,245",
#         "Length": 177,
#         "MPG_City": 20,
#         "MPG_Highway": 29,
#         "MSRP": "$30,795",
#         "Make": "BMW",
#         "Model": "325Ci 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3197,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 2.5,
#         "Horsepower": 184,
#         "Invoice": "$34,800",
#         "Length": 177,
#         "MPG_City": 19,
#         "MPG_Highway": 27,
#         "MSRP": "$37,995",
#         "Make": "BMW",
#         "Model": "325Ci convertible 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3560,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 2.5,
#         "Horsepower": 184,
#         "Invoice": "$27,745",
#         "Length": 176,
#         "MPG_City": 19,
#         "MPG_Highway": 27,
#         "MSRP": "$30,245",
#         "Make": "BMW",
#         "Model": "325xi 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3461,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.0,
#         "Horsepower": 225,
#         "Invoice": "$32,525",
#         "Length": 176,
#         "MPG_City": 20,
#         "MPG_Highway": 30,
#         "MSRP": "$35,495",
#         "Make": "BMW",
#         "Model": "330i 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3285,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.0,
#         "Horsepower": 225,
#         "Invoice": "$33,890",
#         "Length": 176,
#         "MPG_City": 20,
#         "MPG_Highway": 30,
#         "MSRP": "$36,995",
#         "Make": "BMW",
#         "Model": "330Ci 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3285,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.0,
#         "Horsepower": 225,
#         "Invoice": "$34,115",
#         "Length": 176,
#         "MPG_City": 20,
#         "MPG_Highway": 29,
#         "MSRP": "$37,245",
#         "Make": "BMW",
#         "Model": "330xi 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3483,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 2.5,
#         "Horsepower": 184,
#         "Invoice": "$36,620",
#         "Length": 191,
#         "MPG_City": 19,
#         "MPG_Highway": 28,
#         "MSRP": "$39,995",
#         "Make": "BMW",
#         "Model": "525i 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3428,
#         "Wheelbase": 114
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.0,
#         "Horsepower": 225,
#         "Invoice": "$40,530",
#         "Length": 177,
#         "MPG_City": 19,
#         "MPG_Highway": 28,
#         "MSRP": "$44,295",
#         "Make": "BMW",
#         "Model": "330Ci convertible 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3616,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.0,
#         "Horsepower": 225,
#         "Invoice": "$41,170",
#         "Length": 191,
#         "MPG_City": 20,
#         "MPG_Highway": 30,
#         "MSRP": "$44,995",
#         "Make": "BMW",
#         "Model": "530i 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3472,
#         "Wheelbase": 114
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 4.4,
#         "Horsepower": 325,
#         "Invoice": "$50,270",
#         "Length": 191,
#         "MPG_City": 18,
#         "MPG_Highway": 26,
#         "MSRP": "$54,995",
#         "Make": "BMW",
#         "Model": "545iA 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3814,
#         "Wheelbase": 114
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 4.4,
#         "Horsepower": 325,
#         "Invoice": "$63,190",
#         "Length": 198,
#         "MPG_City": 18,
#         "MPG_Highway": 26,
#         "MSRP": "$69,195",
#         "Make": "BMW",
#         "Model": "745i 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 4376,
#         "Wheelbase": 118
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 4.4,
#         "Horsepower": 325,
#         "Invoice": "$66,830",
#         "Length": 204,
#         "MPG_City": 18,
#         "MPG_Highway": 26,
#         "MSRP": "$73,195",
#         "Make": "BMW",
#         "Model": "745Li 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 4464,
#         "Wheelbase": 123
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.2,
#         "Horsepower": 333,
#         "Invoice": "$44,170",
#         "Length": 177,
#         "MPG_City": 16,
#         "MPG_Highway": 24,
#         "MSRP": "$48,195",
#         "Make": "BMW",
#         "Model": "M3 coupe 2dr",
#         "Origin": "Europe",
#         "Type": "Sports",
#         "Weight": 3415,
#         "Wheelbase": 108
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.2,
#         "Horsepower": 333,
#         "Invoice": "$51,815",
#         "Length": 177,
#         "MPG_City": 16,
#         "MPG_Highway": 23,
#         "MSRP": "$56,595",
#         "Make": "BMW",
#         "Model": "M3 convertible 2dr",
#         "Origin": "Europe",
#         "Type": "Sports",
#         "Weight": 3781,
#         "Wheelbase": 108
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 2.5,
#         "Horsepower": 184,
#         "Invoice": "$31,065",
#         "Length": 161,
#         "MPG_City": 20,
#         "MPG_Highway": 28,
#         "MSRP": "$33,895",
#         "Make": "BMW",
#         "Model": "Z4 convertible 2.5i 2dr",
#         "Origin": "Europe",
#         "Type": "Sports",
#         "Weight": 2932,
#         "Wheelbase": 98
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.0,
#         "Horsepower": 225,
#         "Invoice": "$37,575",
#         "Length": 161,
#         "MPG_City": 21,
#         "MPG_Highway": 29,
#         "MSRP": "$41,045",
#         "Make": "BMW",
#         "Model": "Z4 convertible 3.0i 2dr",
#         "Origin": "Europe",
#         "Type": "Sports",
#         "Weight": 2998,
#         "Wheelbase": 98
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 2.5,
#         "Horsepower": 184,
#         "Invoice": "$30,110",
#         "Length": 176,
#         "MPG_City": 19,
#         "MPG_Highway": 26,
#         "MSRP": "$32,845",
#         "Make": "BMW",
#         "Model": "325xi Sport",
#         "Origin": "Europe",
#         "Type": "Wagon",
#         "Weight": 3594,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 4.2,
#         "Horsepower": 275,
#         "Invoice": "$34,357",
#         "Length": 193,
#         "MPG_City": 15,
#         "MPG_Highway": 21,
#         "MSRP": "$37,895",
#         "Make": "Buick",
#         "Model": "Rainier",
#         "Origin": "USA",
#         "Type": "SUV",
#         "Weight": 4600,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.4,
#         "Horsepower": 185,
#         "Invoice": "$24,085",
#         "Length": 187,
#         "MPG_City": 19,
#         "MPG_Highway": 26,
#         "MSRP": "$26,545",
#         "Make": "Buick",
#         "Model": "Rendezvous CX",
#         "Origin": "USA",
#         "Type": "SUV",
#         "Weight": 4024,
#         "Wheelbase": 112
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.1,
#         "Horsepower": 175,
#         "Invoice": "$20,351",
#         "Length": 195,
#         "MPG_City": 20,
#         "MPG_Highway": 30,
#         "MSRP": "$22,180",
#         "Make": "Buick",
#         "Model": "Century Custom 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3353,
#         "Wheelbase": 109
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 205,
#         "Invoice": "$24,282",
#         "Length": 200,
#         "MPG_City": 20,
#         "MPG_Highway": 29,
#         "MSRP": "$26,470",
#         "Make": "Buick",
#         "Model": "LeSabre Custom 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3567,
#         "Wheelbase": 112
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 200,
#         "Invoice": "$22,835",
#         "Length": 196,
#         "MPG_City": 20,
#         "MPG_Highway": 30,
#         "MSRP": "$24,895",
#         "Make": "Buick",
#         "Model": "Regal LS 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3461,
#         "Wheelbase": 109
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 240,
#         "Invoice": "$26,047",
#         "Length": 196,
#         "MPG_City": 18,
#         "MPG_Highway": 28,
#         "MSRP": "$28,345",
#         "Make": "Buick",
#         "Model": "Regal GS 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3536,
#         "Wheelbase": 109
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 205,
#         "Invoice": "$29,566",
#         "Length": 200,
#         "MPG_City": 20,
#         "MPG_Highway": 29,
#         "MSRP": "$32,245",
#         "Make": "Buick",
#         "Model": "LeSabre Limited 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3591,
#         "Wheelbase": 112
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 205,
#         "Invoice": "$32,244",
#         "Length": 207,
#         "MPG_City": 20,
#         "MPG_Highway": 29,
#         "MSRP": "$35,545",
#         "Make": "Buick",
#         "Model": "Park Avenue 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3778,
#         "Wheelbase": 114
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 240,
#         "Invoice": "$36,927",
#         "Length": 207,
#         "MPG_City": 18,
#         "MPG_Highway": 28,
#         "MSRP": "$40,720",
#         "Make": "Buick",
#         "Model": "Park Avenue Ultra 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3909,
#         "Wheelbase": 114
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 5.3,
#         "Horsepower": 295,
#         "Invoice": "$48,377",
#         "Length": 199,
#         "MPG_City": 14,
#         "MPG_Highway": 18,
#         "MSRP": "$52,795",
#         "Make": "Cadillac",
#         "Model": "Escalade",
#         "Origin": "USA",
#         "Type": "SUV",
#         "Weight": 5367,
#         "Wheelbase": 116
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 4.6,
#         "Horsepower": 320,
#         "Invoice": "$43,523",
#         "Length": 195,
#         "MPG_City": 16,
#         "MPG_Highway": 21,
#         "MSRP": "$46,995",
#         "Make": "Cadillac",
#         "Model": "SRX V8",
#         "Origin": "USA",
#         "Type": "SUV",
#         "Weight": 4302,
#         "Wheelbase": 116
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.6,
#         "Horsepower": 255,
#         "Invoice": "$28,575",
#         "Length": 190,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$30,835",
#         "Make": "Cadillac",
#         "Model": "CTS VVT 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3694,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 4.6,
#         "Horsepower": 275,
#         "Invoice": "$41,650",
#         "Length": 207,
#         "MPG_City": 18,
#         "MPG_Highway": 26,
#         "MSRP": "$45,445",
#         "Make": "Cadillac",
#         "Model": "Deville 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3984,
#         "Wheelbase": 115
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 4.6,
#         "Horsepower": 300,
#         "Invoice": "$46,362",
#         "Length": 207,
#         "MPG_City": 18,
#         "MPG_Highway": 26,
#         "MSRP": "$50,595",
#         "Make": "Cadillac",
#         "Model": "Deville DTS 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 4044,
#         "Wheelbase": 115
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 4.6,
#         "Horsepower": 275,
#         "Invoice": "$43,841",
#         "Length": 201,
#         "MPG_City": 18,
#         "MPG_Highway": 26,
#         "MSRP": "$47,955",
#         "Make": "Cadillac",
#         "Model": "Seville SLS 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3992,
#         "Wheelbase": 112
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 4.6,
#         "Horsepower": 320,
#         "Invoice": "$70,546",
#         "Length": 178,
#         "MPG_City": 17,
#         "MPG_Highway": 25,
#         "MSRP": "$76,200",
#         "Make": "Cadillac",
#         "Model": "XLR convertible 2dr",
#         "Origin": "USA",
#         "Type": "Sports",
#         "Weight": 3647,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 6.0,
#         "Horsepower": 345,
#         "Invoice": "$48,541",
#         "Length": 221,
#         "MPG_City": 13,
#         "MPG_Highway": 17,
#         "MSRP": "$52,975",
#         "Make": "Cadillac",
#         "Model": "Escalade EXT",
#         "Origin": "USA",
#         "Type": "Truck",
#         "Weight": 5879,
#         "Wheelbase": 130
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 5.3,
#         "Horsepower": 295,
#         "Invoice": "$37,422",
#         "Length": 219,
#         "MPG_City": 14,
#         "MPG_Highway": 18,
#         "MSRP": "$42,735",
#         "Make": "Chevrolet",
#         "Model": "Suburban 1500 LT",
#         "Origin": "USA",
#         "Type": "SUV",
#         "Weight": 4947,
#         "Wheelbase": 130
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 5.3,
#         "Horsepower": 295,
#         "Invoice": "$36,287",
#         "Length": 197,
#         "MPG_City": 14,
#         "MPG_Highway": 18,
#         "MSRP": "$41,465",
#         "Make": "Chevrolet",
#         "Model": "Tahoe LT",
#         "Origin": "USA",
#         "Type": "SUV",
#         "Weight": 5050,
#         "Wheelbase": 116
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 4.2,
#         "Horsepower": 275,
#         "Invoice": "$27,479",
#         "Length": 192,
#         "MPG_City": 16,
#         "MPG_Highway": 21,
#         "MSRP": "$30,295",
#         "Make": "Chevrolet",
#         "Model": "TrailBlazer LT",
#         "Origin": "USA",
#         "Type": "SUV",
#         "Weight": 4425,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.5,
#         "Horsepower": 165,
#         "Invoice": "$19,108",
#         "Length": 163,
#         "MPG_City": 19,
#         "MPG_Highway": 22,
#         "MSRP": "$20,255",
#         "Make": "Chevrolet",
#         "Model": "Tracker",
#         "Origin": "USA",
#         "Type": "SUV",
#         "Weight": 2866,
#         "Wheelbase": 98
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.6,
#         "Horsepower": 103,
#         "Invoice": "$10,965",
#         "Length": 167,
#         "MPG_City": 28,
#         "MPG_Highway": 34,
#         "MSRP": "$11,690",
#         "Make": "Chevrolet",
#         "Model": "Aveo 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 2370,
#         "Wheelbase": 98
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.6,
#         "Horsepower": 103,
#         "Invoice": "$11,802",
#         "Length": 153,
#         "MPG_City": 28,
#         "MPG_Highway": 34,
#         "MSRP": "$12,585",
#         "Make": "Chevrolet",
#         "Model": "Aveo LS 4dr hatch",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 2348,
#         "Wheelbase": 98
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.2,
#         "Horsepower": 140,
#         "Invoice": "$13,697",
#         "Length": 183,
#         "MPG_City": 26,
#         "MPG_Highway": 37,
#         "MSRP": "$14,610",
#         "Make": "Chevrolet",
#         "Model": "Cavalier 2dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 2617,
#         "Wheelbase": 104
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.2,
#         "Horsepower": 140,
#         "Invoice": "$13,884",
#         "Length": 183,
#         "MPG_City": 26,
#         "MPG_Highway": 37,
#         "MSRP": "$14,810",
#         "Make": "Chevrolet",
#         "Model": "Cavalier 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 2676,
#         "Wheelbase": 104
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.2,
#         "Horsepower": 140,
#         "Invoice": "$15,357",
#         "Length": 183,
#         "MPG_City": 26,
#         "MPG_Highway": 37,
#         "MSRP": "$16,385",
#         "Make": "Chevrolet",
#         "Model": "Cavalier LS 2dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 2617,
#         "Wheelbase": 104
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.4,
#         "Horsepower": 180,
#         "Invoice": "$20,095",
#         "Length": 200,
#         "MPG_City": 21,
#         "MPG_Highway": 32,
#         "MSRP": "$21,900",
#         "Make": "Chevrolet",
#         "Model": "Impala 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3465,
#         "Wheelbase": 111
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.2,
#         "Horsepower": 145,
#         "Invoice": "$17,434",
#         "Length": 188,
#         "MPG_City": 24,
#         "MPG_Highway": 34,
#         "MSRP": "$18,995",
#         "Make": "Chevrolet",
#         "Model": "Malibu 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3174,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.5,
#         "Horsepower": 200,
#         "Invoice": "$18,639",
#         "Length": 188,
#         "MPG_City": 22,
#         "MPG_Highway": 30,
#         "MSRP": "$20,370",
#         "Make": "Chevrolet",
#         "Model": "Malibu LS 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3297,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.4,
#         "Horsepower": 180,
#         "Invoice": "$20,026",
#         "Length": 198,
#         "MPG_City": 21,
#         "MPG_Highway": 32,
#         "MSRP": "$21,825",
#         "Make": "Chevrolet",
#         "Model": "Monte Carlo LS 2dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3340,
#         "Wheelbase": 111
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 200,
#         "Invoice": "$22,931",
#         "Length": 200,
#         "MPG_City": 20,
#         "MPG_Highway": 30,
#         "MSRP": "$25,000",
#         "Make": "Chevrolet",
#         "Model": "Impala LS 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3476,
#         "Wheelbase": 111
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 240,
#         "Invoice": "$25,672",
#         "Length": 200,
#         "MPG_City": 18,
#         "MPG_Highway": 28,
#         "MSRP": "$27,995",
#         "Make": "Chevrolet",
#         "Model": "Impala SS 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3606,
#         "Wheelbase": 111
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.5,
#         "Horsepower": 200,
#         "Invoice": "$21,551",
#         "Length": 188,
#         "MPG_City": 23,
#         "MPG_Highway": 32,
#         "MSRP": "$23,495",
#         "Make": "Chevrolet",
#         "Model": "Malibu LT 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3315,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 200,
#         "Invoice": "$22,222",
#         "Length": 198,
#         "MPG_City": 18,
#         "MPG_Highway": 28,
#         "MSRP": "$24,225",
#         "Make": "Chevrolet",
#         "Model": "Monte Carlo SS 2dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3434,
#         "Wheelbase": 111
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 4.3,
#         "Horsepower": 190,
#         "Invoice": "$23,954",
#         "Length": 190,
#         "MPG_City": 14,
#         "MPG_Highway": 17,
#         "MSRP": "$26,395",
#         "Make": "Chevrolet",
#         "Model": "Astro",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 4605,
#         "Wheelbase": 111
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.4,
#         "Horsepower": 185,
#         "Invoice": "$24,518",
#         "Length": 187,
#         "MPG_City": 19,
#         "MPG_Highway": 26,
#         "MSRP": "$27,020",
#         "Make": "Chevrolet",
#         "Model": "Venture LS",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3699,
#         "Wheelbase": 112
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 5.7,
#         "Horsepower": 350,
#         "Invoice": "$39,068",
#         "Length": 180,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$44,535",
#         "Make": "Chevrolet",
#         "Model": "Corvette 2dr",
#         "Origin": "USA",
#         "Type": "Sports",
#         "Weight": 3246,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 5.7,
#         "Horsepower": 350,
#         "Invoice": "$45,193",
#         "Length": 180,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$51,535",
#         "Make": "Chevrolet",
#         "Model": "Corvette convertible 2dr",
#         "Origin": "USA",
#         "Type": "Sports",
#         "Weight": 3248,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 5.3,
#         "Horsepower": 295,
#         "Invoice": "$31,689",
#         "Length": 222,
#         "MPG_City": 14,
#         "MPG_Highway": 18,
#         "MSRP": "$36,100",
#         "Make": "Chevrolet",
#         "Model": "Avalanche 1500",
#         "Origin": "USA",
#         "Type": "Truck",
#         "Weight": 5678,
#         "Wheelbase": 130
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "All",
#         "EngineSize": 2.8,
#         "Horsepower": 175,
#         "Invoice": "$17,070",
#         "Length": 192,
#         "MPG_City": 18,
#         "MPG_Highway": 23,
#         "MSRP": "$18,760",
#         "Make": "Chevrolet",
#         "Model": "Colorado Z85",
#         "Origin": "USA",
#         "Type": "Truck",
#         "Weight": 3623,
#         "Wheelbase": 111
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 4.3,
#         "Horsepower": 200,
#         "Invoice": "$18,480",
#         "Length": 206,
#         "MPG_City": 15,
#         "MPG_Highway": 21,
#         "MSRP": "$20,310",
#         "Make": "Chevrolet",
#         "Model": "Silverado 1500 Regular Cab",
#         "Origin": "USA",
#         "Type": "Truck",
#         "Weight": 4142,
#         "Wheelbase": 119
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 6.0,
#         "Horsepower": 300,
#         "Invoice": "$35,399",
#         "Length": 238,
#         "MPG_City": 13,
#         "MPG_Highway": 17,
#         "MSRP": "$40,340",
#         "Make": "Chevrolet",
#         "Model": "Silverado SS",
#         "Origin": "USA",
#         "Type": "Truck",
#         "Weight": 4804,
#         "Wheelbase": 144
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 5.3,
#         "Horsepower": 300,
#         "Invoice": "$39,306",
#         "Length": 191,
#         "MPG_City": 16,
#         "MPG_Highway": 19,
#         "MSRP": "$41,995",
#         "Make": "Chevrolet",
#         "Model": "SSR",
#         "Origin": "USA",
#         "Type": "Truck",
#         "Weight": 4760,
#         "Wheelbase": 116
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.5,
#         "Horsepower": 200,
#         "Invoice": "$20,394",
#         "Length": 188,
#         "MPG_City": 22,
#         "MPG_Highway": 30,
#         "MSRP": "$22,225",
#         "Make": "Chevrolet",
#         "Model": "Malibu Maxx LS",
#         "Origin": "USA",
#         "Type": "Wagon",
#         "Weight": 3458,
#         "Wheelbase": 112
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 150,
#         "Invoice": "$16,919",
#         "Length": 169,
#         "MPG_City": 22,
#         "MPG_Highway": 29,
#         "MSRP": "$17,985",
#         "Make": "Chrysler",
#         "Model": "PT Cruiser 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3101,
#         "Wheelbase": 103
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 150,
#         "Invoice": "$20,573",
#         "Length": 169,
#         "MPG_City": 22,
#         "MPG_Highway": 29,
#         "MSRP": "$22,000",
#         "Make": "Chrysler",
#         "Model": "PT Cruiser Limited 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3105,
#         "Wheelbase": 103
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 150,
#         "Invoice": "$17,805",
#         "Length": 191,
#         "MPG_City": 22,
#         "MPG_Highway": 30,
#         "MSRP": "$19,090",
#         "Make": "Chrysler",
#         "Model": "Sebring 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3173,
#         "Wheelbase": 108
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.7,
#         "Horsepower": 200,
#         "Invoice": "$20,284",
#         "Length": 191,
#         "MPG_City": 21,
#         "MPG_Highway": 28,
#         "MSRP": "$21,840",
#         "Make": "Chrysler",
#         "Model": "Sebring Touring 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3222,
#         "Wheelbase": 108
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.5,
#         "Horsepower": 250,
#         "Invoice": "$27,797",
#         "Length": 198,
#         "MPG_City": 18,
#         "MPG_Highway": 27,
#         "MSRP": "$29,865",
#         "Make": "Chrysler",
#         "Model": "300M 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3581,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.7,
#         "Horsepower": 200,
#         "Invoice": "$22,452",
#         "Length": 208,
#         "MPG_City": 21,
#         "MPG_Highway": 29,
#         "MSRP": "$24,130",
#         "Make": "Chrysler",
#         "Model": "Concorde LX 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3479,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.5,
#         "Horsepower": 232,
#         "Invoice": "$24,909",
#         "Length": 208,
#         "MPG_City": 19,
#         "MPG_Highway": 27,
#         "MSRP": "$26,860",
#         "Make": "Chrysler",
#         "Model": "Concorde LXi 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3548,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 220,
#         "Invoice": "$24,172",
#         "Length": 169,
#         "MPG_City": 21,
#         "MPG_Highway": 27,
#         "MSRP": "$25,955",
#         "Make": "Chrysler",
#         "Model": "PT Cruiser GT 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3217,
#         "Wheelbase": 103
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 150,
#         "Invoice": "$23,451",
#         "Length": 194,
#         "MPG_City": 22,
#         "MPG_Highway": 30,
#         "MSRP": "$25,215",
#         "Make": "Chrysler",
#         "Model": "Sebring convertible 2dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3357,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.5,
#         "Horsepower": 255,
#         "Invoice": "$30,884",
#         "Length": 198,
#         "MPG_City": 18,
#         "MPG_Highway": 27,
#         "MSRP": "$33,295",
#         "Make": "Chrysler",
#         "Model": "300M Special Edition 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3650,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.7,
#         "Horsepower": 200,
#         "Invoice": "$28,613",
#         "Length": 194,
#         "MPG_City": 21,
#         "MPG_Highway": 28,
#         "MSRP": "$30,950",
#         "Make": "Chrysler",
#         "Model": "Sebring Limited convertible 2dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3448,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.3,
#         "Horsepower": 180,
#         "Invoice": "$25,371",
#         "Length": 201,
#         "MPG_City": 19,
#         "MPG_Highway": 26,
#         "MSRP": "$27,490",
#         "Make": "Chrysler",
#         "Model": "Town and Country LX",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 4068,
#         "Wheelbase": 119
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.8,
#         "Horsepower": 215,
#         "Invoice": "$35,063",
#         "Length": 201,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$38,380",
#         "Make": "Chrysler",
#         "Model": "Town and Country Limited",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 4331,
#         "Wheelbase": 119
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.2,
#         "Horsepower": 215,
#         "Invoice": "$32,033",
#         "Length": 160,
#         "MPG_City": 17,
#         "MPG_Highway": 25,
#         "MSRP": "$34,495",
#         "Make": "Chrysler",
#         "Model": "Crossfire 2dr",
#         "Origin": "USA",
#         "Type": "Sports",
#         "Weight": 3060,
#         "Wheelbase": 95
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.5,
#         "Horsepower": 250,
#         "Invoice": "$28,725",
#         "Length": 199,
#         "MPG_City": 17,
#         "MPG_Highway": 23,
#         "MSRP": "$31,230",
#         "Make": "Chrysler",
#         "Model": "Pacifica",
#         "Origin": "USA",
#         "Type": "Wagon",
#         "Weight": 4675,
#         "Wheelbase": 116
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "All",
#         "EngineSize": 4.7,
#         "Horsepower": 230,
#         "Invoice": "$29,472",
#         "Length": 201,
#         "MPG_City": 15,
#         "MPG_Highway": 21,
#         "MSRP": "$32,235",
#         "Make": "Dodge",
#         "Model": "Durango SLT",
#         "Origin": "USA",
#         "Type": "SUV",
#         "Weight": 4987,
#         "Wheelbase": 119
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.0,
#         "Horsepower": 132,
#         "Invoice": "$12,849",
#         "Length": 174,
#         "MPG_City": 29,
#         "MPG_Highway": 36,
#         "MSRP": "$13,670",
#         "Make": "Dodge",
#         "Model": "Neon SE 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 2581,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.0,
#         "Horsepower": 132,
#         "Invoice": "$14,086",
#         "Length": 174,
#         "MPG_City": 29,
#         "MPG_Highway": 36,
#         "MSRP": "$15,040",
#         "Make": "Dodge",
#         "Model": "Neon SXT 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 2626,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.7,
#         "Horsepower": 200,
#         "Invoice": "$20,502",
#         "Length": 204,
#         "MPG_City": 21,
#         "MPG_Highway": 29,
#         "MSRP": "$22,035",
#         "Make": "Dodge",
#         "Model": "Intrepid SE 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3469,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 150,
#         "Invoice": "$17,512",
#         "Length": 191,
#         "MPG_City": 21,
#         "MPG_Highway": 28,
#         "MSRP": "$18,820",
#         "Make": "Dodge",
#         "Model": "Stratus SXT 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3182,
#         "Wheelbase": 108
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 150,
#         "Invoice": "$18,821",
#         "Length": 191,
#         "MPG_City": 21,
#         "MPG_Highway": 28,
#         "MSRP": "$20,220",
#         "Make": "Dodge",
#         "Model": "Stratus SE 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3175,
#         "Wheelbase": 108
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.5,
#         "Horsepower": 232,
#         "Invoice": "$23,058",
#         "Length": 204,
#         "MPG_City": 18,
#         "MPG_Highway": 27,
#         "MSRP": "$24,885",
#         "Make": "Dodge",
#         "Model": "Intrepid ES 4dr",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3487,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 150,
#         "Invoice": "$20,508",
#         "Length": 189,
#         "MPG_City": 20,
#         "MPG_Highway": 26,
#         "MSRP": "$21,795",
#         "Make": "Dodge",
#         "Model": "Caravan SE",
#         "Origin": "USA",
#         "Type": "Sedan",
#         "Weight": 3862,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.8,
#         "Horsepower": 215,
#         "Invoice": "$29,812",
#         "Length": 201,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$32,660",
# ...
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 3362,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.3,
#         "Horsepower": 225,
#         "Invoice": "$23,908",
#         "Length": 193,
#         "MPG_City": 20,
#         "MPG_Highway": 29,
#         "MSRP": "$26,510",
#         "Make": "Toyota",
#         "Model": "Camry Solara SLE V6 2dr",
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 3439,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.0,
#         "Horsepower": 210,
#         "Invoice": "$27,271",
#         "Length": 192,
#         "MPG_City": 21,
#         "MPG_Highway": 29,
#         "MSRP": "$30,920",
#         "Make": "Toyota",
#         "Model": "Avalon XLS 4dr",
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 3439,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.3,
#         "Horsepower": 230,
#         "Invoice": "$21,198",
#         "Length": 200,
#         "MPG_City": 19,
#         "MPG_Highway": 27,
#         "MSRP": "$23,495",
#         "Make": "Toyota",
#         "Model": "Sienna CE",
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 4120,
#         "Wheelbase": 119
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 3.3,
#         "Horsepower": 230,
#         "Invoice": "$25,690",
#         "Length": 200,
#         "MPG_City": 19,
#         "MPG_Highway": 27,
#         "MSRP": "$28,800",
#         "Make": "Toyota",
#         "Model": "Sienna XLE Limited",
#         "Origin": "Asia",
#         "Type": "Sedan",
#         "Weight": 4165,
#         "Wheelbase": 119
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.8,
#         "Horsepower": 180,
#         "Invoice": "$20,363",
#         "Length": 171,
#         "MPG_City": 24,
#         "MPG_Highway": 33,
#         "MSRP": "$22,570",
#         "Make": "Toyota",
#         "Model": "Celica GT-S 2dr",
#         "Origin": "Asia",
#         "Type": "Sports",
#         "Weight": 2500,
#         "Wheelbase": 102
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 1.8,
#         "Horsepower": 138,
#         "Invoice": "$22,787",
#         "Length": 153,
#         "MPG_City": 26,
#         "MPG_Highway": 32,
#         "MSRP": "$25,130",
#         "Make": "Toyota",
#         "Model": "MR2 Spyder convertible 2dr",
#         "Origin": "Asia",
#         "Type": "Sports",
#         "Weight": 2195,
#         "Wheelbase": 97
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 2.4,
#         "Horsepower": 142,
#         "Invoice": "$11,879",
#         "Length": 191,
#         "MPG_City": 22,
#         "MPG_Highway": 27,
#         "MSRP": "$12,800",
#         "Make": "Toyota",
#         "Model": "Tacoma",
#         "Origin": "Asia",
#         "Type": "Truck",
#         "Weight": 2750,
#         "Wheelbase": 103
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Rear",
#         "EngineSize": 3.4,
#         "Horsepower": 190,
#         "Invoice": "$14,978",
#         "Length": 218,
#         "MPG_City": 16,
#         "MPG_Highway": 18,
#         "MSRP": "$16,495",
#         "Make": "Toyota",
#         "Model": "Tundra Regular Cab V6",
#         "Origin": "Asia",
#         "Type": "Truck",
#         "Weight": 3925,
#         "Wheelbase": 128
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.4,
#         "Horsepower": 190,
#         "Invoice": "$23,520",
#         "Length": 218,
#         "MPG_City": 14,
#         "MPG_Highway": 17,
#         "MSRP": "$25,935",
#         "Make": "Toyota",
#         "Model": "Tundra Access Cab V6 SR5",
#         "Origin": "Asia",
#         "Type": "Truck",
#         "Weight": 4435,
#         "Wheelbase": 128
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.8,
#         "Horsepower": 130,
#         "Invoice": "$15,156",
#         "Length": 171,
#         "MPG_City": 29,
#         "MPG_Highway": 36,
#         "MSRP": "$16,695",
#         "Make": "Toyota",
#         "Model": "Matrix XR",
#         "Origin": "Asia",
#         "Type": "Wagon",
#         "Weight": 2679,
#         "Wheelbase": 102
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 3.2,
#         "Horsepower": 220,
#         "Invoice": "$32,243",
#         "Length": 187,
#         "MPG_City": 15,
#         "MPG_Highway": 20,
#         "MSRP": "$35,515",
#         "Make": "Volkswagen",
#         "Model": "Touareg V6",
#         "Origin": "Europe",
#         "Type": "SUV",
#         "Weight": 5086,
#         "Wheelbase": 112
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.0,
#         "Horsepower": 115,
#         "Invoice": "$17,478",
#         "Length": 165,
#         "MPG_City": 24,
#         "MPG_Highway": 31,
#         "MSRP": "$18,715",
#         "Make": "Volkswagen",
#         "Model": "Golf GLS 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 2897,
#         "Wheelbase": 99
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.8,
#         "Horsepower": 180,
#         "Invoice": "$18,109",
#         "Length": 168,
#         "MPG_City": 24,
#         "MPG_Highway": 31,
#         "MSRP": "$19,825",
#         "Make": "Volkswagen",
#         "Model": "GTI 1.8T 2dr hatch",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 2934,
#         "Wheelbase": 99
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.9,
#         "Horsepower": 100,
#         "Invoice": "$19,638",
#         "Length": 172,
#         "MPG_City": 38,
#         "MPG_Highway": 46,
#         "MSRP": "$21,055",
#         "Make": "Volkswagen",
#         "Model": "Jetta GLS TDI 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3003,
#         "Wheelbase": 99
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.8,
#         "Horsepower": 150,
#         "Invoice": "$19,638",
#         "Length": 161,
#         "MPG_City": 24,
#         "MPG_Highway": 31,
#         "MSRP": "$21,055",
#         "Make": "Volkswagen",
#         "Model": "New Beetle GLS 1.8T 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 2820,
#         "Wheelbase": 99
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.8,
#         "Horsepower": 200,
#         "Invoice": "$21,686",
#         "Length": 172,
#         "MPG_City": 21,
#         "MPG_Highway": 30,
#         "MSRP": "$23,785",
#         "Make": "Volkswagen",
#         "Model": "Jetta GLI VR6 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3179,
#         "Wheelbase": 99
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.0,
#         "Horsepower": 115,
#         "Invoice": "$21,689",
#         "Length": 161,
#         "MPG_City": 24,
#         "MPG_Highway": 30,
#         "MSRP": "$23,215",
#         "Make": "Volkswagen",
#         "Model": "New Beetle GLS convertible 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3082,
#         "Wheelbase": 99
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.8,
#         "Horsepower": 170,
#         "Invoice": "$21,898",
#         "Length": 185,
#         "MPG_City": 22,
#         "MPG_Highway": 31,
#         "MSRP": "$23,955",
#         "Make": "Volkswagen",
#         "Model": "Passat GLS 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3241,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.8,
#         "Horsepower": 190,
#         "Invoice": "$30,583",
#         "Length": 185,
#         "MPG_City": 19,
#         "MPG_Highway": 26,
#         "MSRP": "$33,180",
#         "Make": "Volkswagen",
#         "Model": "Passat GLX V6 4MOTION 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3721,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 4.0,
#         "Horsepower": 270,
#         "Invoice": "$36,052",
#         "Length": 185,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$39,235",
#         "Make": "Volkswagen",
#         "Model": "Passat W8 4MOTION 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3953,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 4.2,
#         "Horsepower": 335,
#         "Invoice": "$59,912",
#         "Length": 204,
#         "MPG_City": 16,
#         "MPG_Highway": 22,
#         "MSRP": "$65,000",
#         "Make": "Volkswagen",
#         "Model": "Phaeton 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 5194,
#         "Wheelbase": 118
#       },
#       {
#         "Cylinders": 12.0,
#         "DriveTrain": "Front",
#         "EngineSize": 6.0,
#         "Horsepower": 420,
#         "Invoice": "$69,130",
#         "Length": 204,
#         "MPG_City": 12,
#         "MPG_Highway": 19,
#         "MSRP": "$75,000",
#         "Make": "Volkswagen",
#         "Model": "Phaeton W12 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 5399,
#         "Wheelbase": 118
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.0,
#         "Horsepower": 115,
#         "Invoice": "$17,427",
#         "Length": 174,
#         "MPG_City": 24,
#         "MPG_Highway": 30,
#         "MSRP": "$19,005",
#         "Make": "Volkswagen",
#         "Model": "Jetta GL",
#         "Origin": "Europe",
#         "Type": "Wagon",
#         "Weight": 3034,
#         "Wheelbase": 99
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.8,
#         "Horsepower": 170,
#         "Invoice": "$22,801",
#         "Length": 184,
#         "MPG_City": 22,
#         "MPG_Highway": 31,
#         "MSRP": "$24,955",
#         "Make": "Volkswagen",
#         "Model": "Passat GLS 1.8T",
#         "Origin": "Europe",
#         "Type": "Wagon",
#         "Weight": 3338,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 8.0,
#         "DriveTrain": "Front",
#         "EngineSize": 4.0,
#         "Horsepower": 270,
#         "Invoice": "$36,956",
#         "Length": 184,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$40,235",
#         "Make": "Volkswagen",
#         "Model": "Passat W8",
#         "Origin": "Europe",
#         "Type": "Wagon",
#         "Weight": 4067,
#         "Wheelbase": 106
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "All",
#         "EngineSize": 2.9,
#         "Horsepower": 268,
#         "Invoice": "$38,851",
#         "Length": 189,
#         "MPG_City": 15,
#         "MPG_Highway": 20,
#         "MSRP": "$41,250",
#         "Make": "Volvo",
#         "Model": "XC90 T6",
#         "Origin": "Europe",
#         "Type": "SUV",
#         "Weight": 4638,
#         "Wheelbase": 113
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.9,
#         "Horsepower": 170,
#         "Invoice": "$23,701",
#         "Length": 178,
#         "MPG_City": 22,
#         "MPG_Highway": 29,
#         "MSRP": "$25,135",
#         "Make": "Volvo",
#         "Model": "S40 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 2767,
#         "Wheelbase": 101
#       },
#       {
#         "Cylinders": 5.0,
#         "DriveTrain": "All",
#         "EngineSize": 2.5,
#         "Horsepower": 208,
#         "Invoice": "$29,916",
#         "Length": 180,
#         "MPG_City": 20,
#         "MPG_Highway": 27,
#         "MSRP": "$31,745",
#         "Make": "Volvo",
#         "Model": "S60 2.5 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3903,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 5.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.3,
#         "Horsepower": 247,
#         "Invoice": "$32,902",
#         "Length": 180,
#         "MPG_City": 20,
#         "MPG_Highway": 28,
#         "MSRP": "$34,845",
#         "Make": "Volvo",
#         "Model": "S60 T5 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3766,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 5.0,
#         "DriveTrain": "All",
#         "EngineSize": 2.5,
#         "Horsepower": 300,
#         "Invoice": "$35,382",
#         "Length": 181,
#         "MPG_City": 18,
#         "MPG_Highway": 25,
#         "MSRP": "$37,560",
#         "Make": "Volvo",
#         "Model": "S60 R 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3571,
#         "Wheelbase": 107
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.9,
#         "Horsepower": 208,
#         "Invoice": "$35,542",
#         "Length": 190,
#         "MPG_City": 20,
#         "MPG_Highway": 28,
#         "MSRP": "$37,730",
#         "Make": "Volvo",
#         "Model": "S80 2.9 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3576,
#         "Wheelbase": 110
#       },
#       {
#         "Cylinders": 5.0,
#         "DriveTrain": "All",
#         "EngineSize": 2.5,
#         "Horsepower": 194,
#         "Invoice": "$35,688",
#         "Length": 190,
#         "MPG_City": 20,
#         "MPG_Highway": 27,
#         "MSRP": "$37,885",
#         "Make": "Volvo",
#         "Model": "S80 2.5T 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3691,
#         "Wheelbase": 110
#       },
#       {
#         "Cylinders": 5.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.4,
#         "Horsepower": 197,
#         "Invoice": "$38,203",
#         "Length": 186,
#         "MPG_City": 21,
#         "MPG_Highway": 28,
#         "MSRP": "$40,565",
#         "Make": "Volvo",
#         "Model": "C70 LPT convertible 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3450,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 5.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.3,
#         "Horsepower": 242,
#         "Invoice": "$40,083",
#         "Length": 186,
#         "MPG_City": 20,
#         "MPG_Highway": 26,
#         "MSRP": "$42,565",
#         "Make": "Volvo",
#         "Model": "C70 HPT convertible 2dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3450,
#         "Wheelbase": 105
#       },
#       {
#         "Cylinders": 6.0,
#         "DriveTrain": "Front",
#         "EngineSize": 2.9,
#         "Horsepower": 268,
#         "Invoice": "$42,573",
#         "Length": 190,
#         "MPG_City": 19,
#         "MPG_Highway": 26,
#         "MSRP": "$45,210",
#         "Make": "Volvo",
#         "Model": "S80 T6 4dr",
#         "Origin": "Europe",
#         "Type": "Sedan",
#         "Weight": 3653,
#         "Wheelbase": 110
#       },
#       {
#         "Cylinders": 4.0,
#         "DriveTrain": "Front",
#         "EngineSize": 1.9,
#         "Horsepower": 170,
#         "Invoice": "$24,641",
#         "Length": 180,
#         "MPG_City": 22,
#         "MPG_Highway": 29,
#         "MSRP": "$26,135",
#         "Make": "Volvo",
#         "Model": "V40",
#         "Origin": "Europe",
#         "Type": "Wagon",
#         "Weight": 2822,
#         "Wheelbase": 101
#       },
#       {
#         "Cylinders": 5.0,
#         "DriveTrain": "All",
#         "EngineSize": 2.5,
#         "Horsepower": 208,
#         "Invoice": "$33,112",
#         "Length": 186,
#         "MPG_City": 20,
#         "MPG_Highway": 27,
#         "MSRP": "$35,145",
#         "Make": "Volvo",
#         "Model": "XC70",
#         "Origin": "Europe",
#         "Type": "Wagon",
#         "Weight": 3823,
#         "Wheelbase": 109
#       }
#     ]
#   },
#   "encoding": {
#     "x": {
#       "field": "Origin",
#       "type": "nominal"
#     },
#     "y": {
#       "aggregate": "average",
#       "field": "EngineSize",
#       "type": "quantitative"
#     }
#   },
#   "mark": "bar"
# }

# %%
# Changing configurations
alt.Chart(cars).mark_bar().encode(
    alt.Y('Origin', type='nominal'),
    alt.X('average(EngineSize)', type='quantitative', aggregate='average')
)
# Out:
# alt.Chart(...)

# %%
# Changing configurations
alt.Chart(cars).mark_bar(color = 'firebrick').encode(
    alt.Y('Origin', type='nominal', title = 'Category'),
    alt.X('average(EngineSize)', type='quantitative', aggregate='average')
)
# Out:
# alt.Chart(...)

# %%
# Saving Chart
chart.save('chart.html')

# %% [markdown]
# ## **Testing plots**
#
#
# ### **Corrplot**
#
# **Generic plot**

# %%
# Generic example
x, y = np.meshgrid(range(-5, 5), range(-5, 5))
z = x ** 2 + y ** 2

source = pd.DataFrame({'x': x.ravel(),
                     'y': y.ravel(),
                     'z': z.ravel()})

alt.Chart(source).mark_rect().encode(
    x='x:O',
    y='y:O',
    color='z:Q'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# **Cars dataset**
#
# Select columns by it's position number:
#
# https://medium.com/dunder-data/selecting-subsets-of-data-in-pandas-6fcd0170be9c
#
# Plotting heatmap with altair from a dataframe:
#
# https://towardsdatascience.com/altair-plot-deconstruction-visualizing-the-correlation-structure-of-weather-data-38fb5668c5b1

# %%
# Dat preprocessing
data = cars.iloc[:, 9:]
cor_data = data.corr().stack().reset_index()\
            .rename(columns={0: 'correlation', 'level_0': 'variable', 'level_1': 'variable2'}) 

cor_data['correlation_label'] = cor_data['correlation'].map('{:.2f}'.format)  # Round to 2 decimal
cor_data.head()
# Out:
#      variable    variable2  correlation correlation_label
# 0  Horsepower   Horsepower     1.000000              1.00
# 1  Horsepower     MPG_City    -0.676699             -0.68
# 2  Horsepower  MPG_Highway    -0.647195             -0.65
# 3  Horsepower       Weight     0.630796              0.63
# 4  Horsepower    Wheelbase     0.387398              0.39

# %%
# Plotting 
base = alt.Chart(cor_data).encode(
    x='variable2:O',
    y='variable:O'    
)

# The correlation heatmap itself
cor_plot = base.mark_rect().encode(
    color='correlation:Q'
).properties(width=500, height = 500)

text = base.mark_text().encode(
    text='correlation_label',
    color=alt.condition(
        alt.datum.correlation > 0.5, 
        alt.value('white'),
        alt.value('black')
    )
)

cor_plot + text
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### **Histogram**

# %%
alt.Chart(cars).mark_bar().encode(
    alt.X("EngineSize:Q", bin=alt.Bin(maxbins=20)),
    alt.Y('count()', stack=None)
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_circle(size=50).encode(
    x='Horsepower',
    y='MPG_Highway',
    color='Origin',
    tooltip=['Model', 'Origin', 'Horsepower', 'MPG_Highway']).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# # **Plotly**
# ---

# %%
import pandas as pd
import plotly as go
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-1baae4b09b33> in <module>
#       1 import pandas as pd
# ----> 2 import plotly as go
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import sys
# !conda install --yes --prefix {sys.prefix} plotly
# Out:
# EnvironmentLocationNotFound: Not a conda environment: C:\Users\Kamila

# %% [markdown]
# ---
#
# <a href="https://midoritoyota.netlify.app/" target="_blank"><img align="left" src="portfolio.png" title="See my portfolio!"/></a><img align="left" src="espaco.png"/>
#
# <a href="mailto:midori.toyota@gmail.com" target="_blank"><img align="left" src="gmail.png" title="Contact me!"/></a><img align="left" src="espaco.png"/>
#
# <a href="https://www.linkedin.com/in/midoritoyota/" target="_blank"> <img align="left" src="linkedin.png" title="Connect with me on linkedin!" /></a><img align="left" src="espaco.png"/>
#
# <a href="https://github.com/MidoriToyota" target="_blank"> <img align="left" src="github.png" title="Follow me on github!"/></a>
#
# <br/><br/>
